# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'C:\Users\hanis\OneDrive\Desktop\datascience\HR_analytics.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# This dataset contains 1470 records and 35 features.

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# Let's check for nulls in the dataset.

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# There are no null values present in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# Let's check the statistical information of the data.

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# Since this dataset contains may features, let's analyse data with the help of plotting techniques.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# Let's encode the data in categorical columns using encoding techniques.

# %%
object_data=[]
for i in df.columns:
    if(df[i].dtypes=='object'):
        object_data.append(i)
    
object_data
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'Over18',
#  'OverTime']

# %%
for i in object_data:
    print(df[i].unique(),"\n")
# Out:
# ['Yes' 'No']
#
# ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
#
# ['Sales' 'Research & Development' 'Human Resources']
#
# ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
#
# ['Female' 'Male']
#
# ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
#
# ['Single' 'Married' 'Divorced']
#
# ['Y']
#
# ['Yes' 'No']

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()

# %%
for i in object_data:
    df[i]=LE.fit_transform(df[i])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int32
#  2   BusinessTravel            1470 non-null   int32
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int32
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   int32
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   int32
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# By using LabelEncoder, all the object type data are encoded.
#
# Let's analyze the data with the help of graphs

# %%
n=1
plt.figure(figsize=(20,25))
for i in df.columns:
    ax=plt.subplot(7,5,n)
    sns.distplot(x=df[i])
    plt.xlabel(i)
    n+=1
    
plt.show()

# %%
df.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome            0.958118
# Education                  -0.289681
# EducationField              0.550371
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# Over18                      0.000000
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# ...

# %%
skewed_features=[]
for i in df.columns:
    value=df[i].skew()
    if((value<-0.5) | (value>0.5)):
        if(i in object_data):
            continue
        else:    
            skewed_features.append(i)
        print( i ,':', value)
# Out:
# DistanceFromHome : 0.9581179956568269
# JobLevel : 1.0254012829518246
# MonthlyIncome : 1.3698166808390662
# NumCompaniesWorked : 1.026471111968205
# PercentSalaryHike : 0.8211279755780908
# PerformanceRating : 1.921882702142603
# StockOptionLevel : 0.9689803167738937
# TotalWorkingYears : 1.1171718528128527
# TrainingTimesLastYear : 0.5531241710537028
# WorkLifeBalance : -0.5524802990965146
# YearsAtCompany : 1.7645294543422085
# YearsInCurrentRole : 0.9173631562908262
# YearsSinceLastPromotion : 1.9842899833524859
# YearsWithCurrManager : 0.8334509919918475

# %%
for i in skewed_features:
    print(df[i].unique())
# Out:
# [ 1  8  2  3 24 23 27 16 15 26 19 21  5 11  9  7  6 10  4 25 12 18 29 22
#  14 20 28 17 13]
# [2 1 3 4 5]
# [5993 5130 2090 ... 9991 5390 4404]
# [8 1 6 9 0 4 5 2 7 3]
# [11 23 15 12 13 20 22 21 17 14 16 18 19 24 25]
# [3 4]
# [0 1 3 2]
# [ 8 10  7  6 12  1 17  5  3 31 13  0 26 24 22  9 19  2 23 14 15  4 29 28
#  21 25 20 11 16 37 38 30 40 18 36 34 32 33 35 27]
# [0 3 2 5 1 4 6]
# [1 3 2 4]
# [ 6 10  0  8  2  7  1  9  5  4 25  3 12 14 22 15 27 21 17 11 13 37 16 20
#  40 24 33 19 36 18 29 31 32 34 26 30 23]
# [ 4  7  0  2  5  9  8  3  6 13  1 15 14 16 11 10 12 18 17]
# [ 0  1  3  2  7  4  8  6  5 15  9 13 12 10 11 14]
# [ 5  7  0  2  6  8  3 11 17  1  4 12  9 10 15 13 16 14]

# %% [markdown]
# From the above we can observe all the features are categorical except 'MonthlyIncome'. Let's try to reduce skeweness for this feature.

# %%
df['MonthlyIncome']=np.cbrt(df['MonthlyIncome'])
df['MonthlyIncome']=np.cbrt(df['MonthlyIncome'])
df['MonthlyIncome'].skew()
# Out:
# 0.4196135254048344

# %% [markdown]
# Now skeweness is reduced.

# %% [markdown]
# Let's check for outliers present in the dataset.

# %%
n=1
plt.figure(figsize=(20,25))
for i in df.columns:
    ax=plt.subplot(7,5,n)
    sns.boxplot(y=df[i])
    plt.xlabel(i)
    n+=1
    
plt.show()

# %% [markdown]
# From the above we can observe outliers in 'NumCompaniesWorked','PerfornamceRating','StockOptionLevel','TptalWorkingYears','TrainingTimesLastYear','YearsAtCompany','YearsinCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager'.

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
outlier_features=['NumCompaniesWorked','PerformanceRating','StockOptionLevel','TotalWorkingYears', 'TrainingTimesLastYear', 
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']

# %%
for i in outlier_features:
    print(df[i].unique())
# Out:
# [8 1 6 9 0 4 5 2 7 3]
# [3 4]
# [0 1 3 2]
# [ 8 10  7  6 12  1 17  5  3 31 13  0 26 24 22  9 19  2 23 14 15  4 29 28
#  21 25 20 11 16 37 38 30 40 18 36 34 32 33 35 27]
# [0 3 2 5 1 4 6]
# [ 6 10  0  8  2  7  1  9  5  4 25  3 12 14 22 15 27 21 17 11 13 37 16 20
#  40 24 33 19 36 18 29 31 32 34 26 30 23]
# [ 4  7  0  2  5  9  8  3  6 13  1 15 14 16 11 10 12 18 17]
# [ 0  1  3  2  7  4  8  6  5 15  9 13 12 10 11 14]
# [ 5  7  0  2  6  8  3 11 17  1  4 12  9 10 15 13 16 14]

# %%
df['TotalWorkingYears'].unique()
# Out:
# array([ 8, 10,  7,  6, 12,  1, 17,  5,  3, 31, 13,  0, 26, 24, 22,  9, 19,
#         2, 23, 14, 15,  4, 29, 28, 21, 25, 20, 11, 16, 37, 38, 30, 40, 18,
#        36, 34, 32, 33, 35, 27], dtype=int64)

# %%
df['YearsAtCompany'].unique()
# Out:
# array([ 6, 10,  0,  8,  2,  7,  1,  9,  5,  4, 25,  3, 12, 14, 22, 15, 27,
#        21, 17, 11, 13, 37, 16, 20, 40, 24, 33, 19, 36, 18, 29, 31, 32, 34,
#        26, 30, 23], dtype=int64)

# %%
df['YearsSinceLastPromotion'].unique()
# Out:
# array([ 0,  1,  3,  2,  7,  4,  8,  6,  5, 15,  9, 13, 12, 10, 11, 14],
#       dtype=int64)

# %%
df['YearsWithCurrManager'].unique()
# Out:
# array([ 5,  7,  0,  2,  6,  8,  3, 11, 17,  1,  4, 12,  9, 10, 15, 13, 16,
#        14], dtype=int64)

# %% [markdown]
# As per my observation from data, 'TotalWorkingYears','YearsAtCompany','YearsSinceLastPromotion','YearsWithCurrManager' features contain inappropriate data.
# Let's remove outliers with the help of zscore technique.

# %%
from scipy.stats import zscore

# %%
outlier_features=['TotalWorkingYears','YearsAtCompany','YearsSinceLastPromotion','YearsWithCurrManager']
zscore=np.abs(zscore(df[outlier_features]))

zscore>3
# Out:
#       TotalWorkingYears  YearsAtCompany  YearsSinceLastPromotion  \
# 0                 False           False                    False
# 1                 False           False                    False
# 2                 False           False                    False
# 3                 False           False                    False
# 4                 False           False                    False
# ...                 ...             ...                      ...
# 1465              False           False                    False
# 1466              False           False                    False
# 1467              False           False                    False
# 1468              False           False                    False
# 1469              False           False                    False
#
#       YearsWithCurrManager
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ...

# %%
df1=df[(zscore<3).all(axis=1)]
df1.shape
# Out:
# (1396, 35)

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# Now outliers are removed.

# %% [markdown]
# Let's check for correlation of features and variables.

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df1.corr(),annot=True,fmt='.2f')
plt.show()

# %% [markdown]
# From the above we can observe, 'EmployeeCount','Over18','StandardHours' are higly correlated. Let's drop these features.

# %%
df1.drop(columns=['EmployeeCount','Over18','StandardHours'],axis=1,inplace=True)
df1.shape
# Out:
# (1396, 32)

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df1.corr(),annot=True,fmt='.2f')
plt.show()

# %% [markdown]
# Let's use Varience Inflation factor for checking Multi collinearity issue.

# %%
df1.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
x=df1.drop(columns=['Attrition'],axis=1)

# %%
y=df1['Attrition']

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
VIF=pd.DataFrame()
VIF['Features']=x.columns
VIF['values']=[variance_inflation_factor(x,i) for i in range(x.shape[1])]
VIF
# Out:
#                     Features      values
# 0                        Age   32.948173
# 1             BusinessTravel    6.868759
# 2                  DailyRate    5.116739
# 3                 Department   13.662044
# 4           DistanceFromHome    2.316966
# 5                  Education    9.574915
# 6             EducationField    3.925567
# 7             EmployeeNumber    3.987799
# 8    EnvironmentSatisfaction    7.253145
# 9                     Gender    2.555568
# 10                HourlyRate   11.732954
# 11            JobInvolvement   15.838053
# 12                  JobLevel   17.351302
# 13                   JobRole    8.413370
# 14           JobSatisfaction    7.318349
# 15             MaritalStatus    5.981725
# 16             MonthlyIncome  247.591800
# 17               MonthlyRate    5.164020
# 18        NumCompaniesWorked    2.725508
# 19                  OverTime    1.436301
# 20         PercentSalaryHike   44.938736
# 21         PerformanceRating  176.044508
# ...

# %% [markdown]
# From the above we can observe MonthlyIncome, Performance Rating features has high values.Let's drop these features.

# %%
x.drop(columns=['MonthlyIncome','PerformanceRating'],axis=1,inplace=True)
x.shape
# Out:
# (1396, 29)

# %%
VIF=pd.DataFrame()
VIF['Features']=x.columns
VIF['values']=[variance_inflation_factor(x,i) for i in range(x.shape[1])]
VIF
# Out:
#                     Features     values
# 0                        Age  30.235776
# 1             BusinessTravel   6.555816
# 2                  DailyRate   4.991865
# 3                 Department  13.485665
# 4           DistanceFromHome   2.302744
# 5                  Education   9.270909
# 6             EducationField   3.858308
# 7             EmployeeNumber   3.902884
# 8    EnvironmentSatisfaction   7.023479
# 9                     Gender   2.511780
# 10                HourlyRate  10.989706
# 11            JobInvolvement  14.814269
# 12                  JobLevel  11.840248
# 13                   JobRole   8.404493
# 14           JobSatisfaction   7.002950
# 15             MaritalStatus   5.743965
# 16               MonthlyRate   5.007469
# 17        NumCompaniesWorked   2.711458
# 18                  OverTime   1.431367
# 19         PercentSalaryHike  16.122036
# 20  RelationshipSatisfaction   7.136853
# 21          StockOptionLevel   3.326951
# ...

# %% [markdown]
# Let's check if there is class imbalance problem

# %%
y.value_counts()
# Out:
# 0    1167
# 1     229
# Name: Attrition, dtype: int64

# %% [markdown]
# From the above we can observe there are more number of records of '0' type. Let's balance the data.

# %%
from imblearn.over_sampling import SMOTE
SM=SMOTE()
x,y=SM.fit_resample(x,y)
y.value_counts()
# Out:
# 1    1167
# 0    1167
# Name: Attrition, dtype: int64

# %% [markdown]
# Now, lets find Random State and build model.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
max_rand_state=0
max_acc_score=0
for i in range(1,150):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    RFC=RandomForestClassifier()
    RFC.fit(x_train,y_train)
    y_predict=RFC.predict(x_test)
    acc_score=accuracy_score(y_test,y_predict)
    if(acc_score>max_acc_score):
        max_acc_score=acc_score
        max_rand_state=i
        
print("Accuracy score - ",max_acc_score)        
print("Random State - ",max_rand_state)
# Out:
# Accuracy score -  0.9366438356164384
# Random State -  108

# %% [markdown]
# Random state is 108 and Accuracy score is 93%.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=108)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier,BaggingClassifier,RandomForestClassifier,ExtraTreesClassifier

# %%
LR=LogisticRegression()
LR.fit(x_train,y_train)
y_predict_LR=LR.predict(x_test)
acc_score_LR=accuracy_score(y_test,y_predict_LR)
print("Accuracy Score ",acc_score_LR)
# Out:
# Accuracy Score  0.7054794520547946

# %%
DTC=DecisionTreeClassifier()
DTC.fit(x_train,y_train)
y_predict_DTC=DTC.predict(x_test)
acc_score_DTC=accuracy_score(y_test,y_predict_DTC)
print("Accuracy Score ",acc_score_DTC)
# Out:
# Accuracy Score  0.8321917808219178

# %%
Knn=KNeighborsClassifier()
Knn.fit(x_train,y_train)
y_predict_Knn=Knn.predict(x_test)
acc_score_Knn=accuracy_score(y_test,y_predict_Knn)
print("Accuracy Score ",acc_score_Knn)
# Out:
# Accuracy Score  0.7208904109589042

# %%
ABC=AdaBoostClassifier()
ABC.fit(x_train,y_train)
y_predict_ABC=ABC.predict(x_test)
acc_score_ABC=accuracy_score(y_test,y_predict_ABC)
print("Accuracy Score ",acc_score_ABC)
# Out:
# Accuracy Score  0.8801369863013698

# %%
GDT=GradientBoostingClassifier()
GDT.fit(x_train,y_train)
y_predict_GDT=GDT.predict(x_test)
acc_score_GDT=accuracy_score(y_test,y_predict_GDT)
print("Accuracy Score ",acc_score_GDT)
# Out:
# Accuracy Score  0.9006849315068494

# %%
BC=BaggingClassifier()
BC.fit(x_train,y_train)
y_predict_BC=BC.predict(x_test)
acc_score_BC=accuracy_score(y_test,y_predict_BC)
print('Accuracy Score ',acc_score_BC)
# Out:
# Accuracy Score  0.8852739726027398

# %%
RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
y_predict_RFC=RFC.predict(x_test)
acc_score_RFC=accuracy_score(y_test,y_predict_RFC)
print("accuracy score :",acc_score_RFC)
# Out:
# accuracy score : 0.9246575342465754

# %%
ETC=ExtraTreesClassifier()
ETC.fit(x_train,y_train)
y_predict_ETC=ETC.predict(x_test)
acc_score_ETC=accuracy_score(y_test,y_predict_ETC)
print("Accuracy Score ",acc_score_ETC)
# Out:
# Accuracy Score  0.9366438356164384

# %% [markdown]
# From the above we can observe ExtraTreesClassifier is providing highest accuracy score of 93%.
#
# Let's check accuracy score provided by the model is due to overfitting of the model.

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix,classification_report

# %%
score=cross_val_score(RFC,x,y)
mean=score.mean()
print("Difference is ",acc_score_RFC-mean)
# Out:
# Difference is  0.1295844258292278

# %%
score=cross_val_score(LR,x,y)
mean=score.mean()
print("Difference is ",acc_score_LR-mean)
# Out:
# Difference is  0.08853263601597505

# %%
score=cross_val_score(Knn,x,y)
mean=score.mean()
print("Difference is ",acc_score_Knn-mean)
# Out:
# Difference is  0.08893224496465724

# %%
score=cross_val_score(DTC,x,y)
mean=score.mean()
print("Difference is ",acc_score_DTC-mean)
# Out:
# Difference is  0.1202132124786437

# %%
score=cross_val_score(ETC,x,y)
mean=score.mean()
print("Difference is ",acc_score_ETC-mean)
# Out:
# Difference is  0.03688553912067971

# %%
score=cross_val_score(GDT,x,y)
mean=score.mean()
print("Difference is ",acc_score_GDT-mean)
# Out:
# Difference is  0.2559321032082399

# %%
score=cross_val_score(ABC,x,y)
mean=score.mean()
print("Difference is ",acc_score_ABC-mean)
# Out:
# Difference is  0.29149888905017274

# %%
score=cross_val_score(BC,x,y)
mean=score.mean()
print("Difference is ",acc_score_BC-mean)
# Out:
# Difference is  0.1415954842146172

# %% [markdown]
# From the above we can observe cross validation score of ExtraTreesClassifier is less when compared to other models. Let's consider this model as the best model.

# %%
print("Accuracy score - ",accuracy_score(y_test,y_predict_ETC))
print("confusion matrix - \n",confusion_matrix(y_test,y_predict_ETC))
print("classification report - \n",classification_report(y_test,y_predict_ETC))
# Out:
# Accuracy score -  0.9366438356164384
# confusion matrix -
#  [[286  12]
#  [ 25 261]]
# classification report -
#                precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       298
#            1       0.96      0.91      0.93       286
#
#     accuracy                           0.94       584
#    macro avg       0.94      0.94      0.94       584
# weighted avg       0.94      0.94      0.94       584

# %% [markdown]
# Let's tune the paramters and increase the accuracy score of the model

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={'criterion':['gini','entropy'],
      'max_depth':[18,19,20],
      'min_samples_leaf':[2,3,4],
      'min_samples_split':[6,7,8]}
GSV=GridSearchCV(ETC,param_grid=param,n_jobs=-1)
GSV.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=ExtraTreesClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [18, 19, 20],
#                          'min_samples_leaf': [2, 3, 4],
#                          'min_samples_split': [6, 7, 8]})

# %%
GSV.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 20,
#  'min_samples_leaf': 2,
#  'min_samples_split': 6}

# %%
Best_model=ExtraTreesClassifier(criterion='entropy',max_depth=24,min_samples_leaf=2,min_samples_split=6)
Best_model.fit(x_train,y_train)
y_predict=Best_model.predict(x_test)
acc_score=accuracy_score(y_test,y_predict)
print('Accuracy score ',acc_score)
# Out:
# Accuracy score  0.9246575342465754

# %% [markdown]
# After trying multiple values for parameter of ExtraTreesClassifier, default parameters exhibiting more accuracy score.
#
# Let's consider default parameters only.

# %%
print("Accuracy score - ",accuracy_score(y_test,y_predict_ETC))
print("confusion matrix - \n",confusion_matrix(y_test,y_predict_ETC))
print("classification report - \n",classification_report(y_test,y_predict_ETC))
# Out:
# Accuracy score -  0.9366438356164384
# confusion matrix -
#  [[286  12]
#  [ 25 261]]
# classification report -
#                precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       298
#            1       0.96      0.91      0.93       286
#
#     accuracy                           0.94       584
#    macro avg       0.94      0.94      0.94       584
# weighted avg       0.94      0.94      0.94       584

# %% [markdown]
# Let's save the model.

# %%
import pickle
pickle.dump(ETC,open('HR_Analytics_model','wb'))
